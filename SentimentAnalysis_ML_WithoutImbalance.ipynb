# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd /content/gdrive/MyDrive/Belajar\ di\ BisaAi/Data\ Science/OJT/Sentiment\ Analysis
# Out:
# /content/gdrive/MyDrive/Belajar di BisaAi/Data Science/OJT/Sentiment Analysis

# %%
import pandas as pd
import glob

# %%
#Membaca semua data kemudian menggabungkannya menjadi satu
df = pd.DataFrame(columns=['Package Name', 'App Version Code', 'App Version Name',
       'Reviewer Language', 'Device', 'Review Submit Date and Time',
       'Review Submit Millis Since Epoch', 'Review Last Update Date and Time',
       'Review Last Update Millis Since Epoch', 'Star Rating', 'Review Title',
       'Review Text', 'Developer Reply Date and Time',
       'Developer Reply Millis Since Epoch', 'Developer Reply Text',
       'Review Link'])
files = glob.glob(r'*.csv')
for f in files:
    Data = pd.read_csv(f,sep=',',encoding="utf-16")
    df = pd.concat([Data,df])
    print(df.shape)

df.head()
# Out:
# (33, 16)
# (39, 16)
# (46, 16)
# (47, 16)
# (58, 16)
# (96, 16)
# (126, 16)
# (165, 16)
# (176, 16)
# (185, 16)
# (191, 16)
#             Package Name  ...                                        Review Link
# 0  com.pos.bisaaiacademy  ...                                                NaN
# 1  com.pos.bisaaiacademy  ...  http://play.google.com/console/developers/5503...
# 2  com.pos.bisaaiacademy  ...                                                NaN
# 3  com.pos.bisaaiacademy  ...                                                NaN
# 4  com.pos.bisaaiacademy  ...  http://play.google.com/console/developers/5503...
#
# [5 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191 entries, 0 to 32
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Package Name                           191 non-null    object
#  1   App Version Code                       151 non-null    float64
#  2   App Version Name                       151 non-null    object
#  3   Reviewer Language                      191 non-null    object
#  4   Device                                 190 non-null    object
#  5   Review Submit Date and Time            191 non-null    object
#  6   Review Submit Millis Since Epoch       191 non-null    object
#  7   Review Last Update Date and Time       191 non-null    object
#  8   Review Last Update Millis Since Epoch  191 non-null    object
#  9   Star Rating                            191 non-null    object
#  10  Review Title                           0 non-null      float64
#  11  Review Text                            136 non-null    object
#  12  Developer Reply Date and Time          125 non-null    object
#  13  Developer Reply Millis Since Epoch     125 non-null    float64
#  14  Developer Reply Text                   125 non-null    object
#  15  Review Link                            136 non-null    object
# dtypes: float64(3), object(13)
# memory usage: 25.4+ KB

# %%
# Membuat new_df dari df
new_df = df[['Star Rating','Review Text']]
new_df.head()
# Out:
#   Star Rating                                        Review Text
# 0           5                                                NaN
# 1           1  Gak recommended course nya, pas nanya materi k...
# 2           5                                                NaN
# 3           5                                                NaN
# 4           5                              Best AI Training apps

# %%
#Menambahkan kolom sentiment
sentiment = []
for _, row in new_df.iterrows():
  if row['Star Rating'] >= 4:
    sentiment.append('Positif')
  elif row['Star Rating'] == 3:
    sentiment.append('Netral')
  else:
    sentiment.append('Negatif')

new_df['Sentiment'] = sentiment
new_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#   Star Rating                                        Review Text Sentiment
# 0           5                                                NaN   Positif
# 1           1  Gak recommended course nya, pas nanya materi k...   Negatif
# 2           5                                                NaN   Positif
# 3           5                                                NaN   Positif
# 4           5                              Best AI Training apps   Positif

# %%
import numpy as np
#mengganti comment kosong yg positif menjadi bagus
new_df['Review Text'] = np.where((new_df['Review Text'].isna() & new_df.Sentiment.str.contains('Positif')),'bagus',new_df['Review Text'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
new_df.isna().sum()
# Out:
# Star Rating    0
# Review Text    3
# Sentiment      0
# dtype: int64

# %%
#mengganti comment kosong yg selain yg positif menjadi nocomment
new_df['Review Text'] = new_df['Review Text'].fillna('nocomment')
new_df.isna().sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Star Rating    0
# Review Text    0
# Sentiment      0
# dtype: int64

# %%
#Melihat Persebaran Datanya
new_df.groupby(['Sentiment','Star Rating'])['Review Text'].count()
# Out:
# Sentiment  Star Rating
# Negatif    1                7
#            2                7
# Netral     3                5
# Positif    4                9
#            5              163
# Name: Review Text, dtype: int64

# %%
print(new_df['Review Text'].values)
# Out:
# ['bagus'
#  'Gak recommended course nya, pas nanya materi ke mentornya malah dibatasi topiknya padahal masih relevan sama course yg diambil, waktu itu dikasih cp mentor tpi chat gak dibales balas sampe waktu workshop nya habis gak ada balasan, materi juga gak jelas cmn implementasi doang gak ada penjelasan metode nya, youtube lebih membantu sih dibanding ini, semoga bisa di upgrade lgi kualitas mentor dan materinya'
#  'bagus' 'bagus' 'Best AI Training apps'
#  'Jangan buat aplikasi dah kalo kagak bisa dipake' 'bagus'
#  'Gudangnya pengetahuan.' 'bagus' 'bagus' 'bagus' 'bagus'
#  'Untuk kelas excel for analytic nilai quiz nya di perbaiki dong, masa 1 soal nilai nya 5point untuk 10 soal, kalau bener semua cuman dapet 50 sedangkan minimal lulus harus 80'
#  'bagus'
#  'Aplikasinya bagus, akan tetapi ada saran untuk tampilan. Tulisan pada materi di silabus kecil sekali, rumus terkadang tidak muncul. Untuk kompetisi dibedakan dong yang sudah lewat sama yang sedang berlangsung.'
#  'bagus' 'Sangat membantu !!!' 'nocomment'
#  'Kenapa ya ada course yg nilai kuisnya mentok di 50 atau 60 padahal jawabannya sudah yakin benar (sudah berkali2 dicek dan disesuaikan dengan materi)? Mohon bantuannya.'
#  'bagus'
#  'Aplikasi anak bangsa yang luar biasa... Sangat membantu bagi orang yang ingin terjun kedunia IT dan ingin tahu apa itu AI'
#  'bagus'
#  'Aplikasinya sangat membantu banget, bisa nambah ilmu sama relasi, goks dah pokonya 🔥🔥'
#  'Aplikasinya sangat bagus dan kerennn banget buat belajar data science dan AI, recommended'
#  'Great app for learning'
#  'The application is very helpful in understanding basic material' 'bagus'
#  'bagus' 'Mantap dah'
#  'Materinya keren, silabus seperti ringkasan mudah pahami untuk pemula. Di tunggu pengembangan sistem selanjutnya 👍👍👍'
#  'Banyak ilmu daging di dalamnya 😍'
#  'Tempat belajar yang user friendly dan punya komunitas yang ramah. Harus dicoba yah'
#  'Aplikasinya keren banget kak'
#  'Aplikasinya keren abis, baru tahu ternyata juga ada course untuk Machine Learning.'
#  'Aplikasi keren yang ngebantu banget buat belajar dunia digital, apalagi buat saya yg butuh sumber belajar. Mantapp terus kembangkan minn.'
#  'Setelah mengerjakan course gratis menurutku untuk aplikasinya udh bagus ilmu nya sampai ke otak , mungkin buat yang di tugas di quiz ada sedikit lag atau GK bisa scrooll, tapi pas diulang lagi quiz nya bisa lancar aku kurang tau apa karna device ku atau bagaimana 😅, saran tambahkan info atau fitur alur buat belajar tiap course nya , misal kalo mau bisa atau jadi data science urutan mulai course darimana bisa dimulai mungkin bisa sedikit membantu'
#  'bagus'
#  'Aplikasinya bagus, saya baru mencoba untuk course python dasar dan menurut saya materinya mudah dimengerti, mungkin sedikit kekurang dibagian kuis uang terkadang bug tidak bisa scroll Overal good application for learning.'
#  'Mantap' 'Nice app for learning, and easy to use'
#  'Mantap buat latian belajar dan menambah pengalaman'
#  'Keren, materinya juga lengkap 👍' 'Bagus sekali'
#  'Sangat bermanfaat karena tersedia banyak sekali kelas yang sangat membantu kita dan tersedia bootcamp dengan harga yang terjangkau'
#  '👍👍' 'bagus'
#  'Dalam aplikasi ini kita dapat mempelajari materi² yang banyak dibutuhkan didalam dunia IT, materi yang diberikan sangat update sesuai dengan perkembangan zaman. Recomended bgt untuk orang awam yang ingin belajar tentang dunia IT khususnya dalam bidang Ai.'
#  'Terimakasih bisa ai, materi nya sangat bermanfaat'
#  'Materi yang tersedia di aplikasi sangat banyak dan bagus untuk menambah ilmu pengetahuan. 👍👍👍👍'
#  'bagus'
#  'Aplikasi karya anak bangsa yg sangat membantu sekali mengadakan kursus webinar free & berbayar buat orang² pemula, awam, mahasiswa, umum, dan orang ² yg mau belajar lebih dalam lagi mengenal ilmu Artificial Inteligency (AI) yg sedang viral di masa kini. Recommended bgt lah pokoknya. Pengajar nya pun humble dan expert bgt didlm mengajari bidang nya tsb. Ayo tunggu apalagi guys. Buruan download aplikasi nya ini dan langsung pilih kursus yg km inginkan ya. Jgn sampai menyesal di kemudian hari.😊'
#  'Sangat membantu sekali aplikasinya, saya bisa mengenal update terbaru seputar teknologi, dab bisa memperdalam ilmu TI'
#  'Materi yang diberikan cukup padat walaupun Free Course sehingga mampu mengakomodasi materi dasar terutama tentang sistem cerdas.'
#  'Mantap ilmunya.. semoga semakin bermanfaat.'
#  'aplikasi nya menarik , apalagi ada fitur buat freelance , dan lowongan kerja'
#  'Applikasinya keren, ada free course yang bisa kita pelajari, ada course berbayar juga yang ngga kalah menarik buat kita yang tertarik di dunia IT, AI, Pemrograman komputer, Bahasa Pemrograman, dan Internet of things! Sangat bermanfaat.'
#  'Jujur, saya senang sekali bisa menemukan aplikasi Bisa AI, karena sangat membantu saya belajar di bidang yang saya sukai. Terima kasih bisa ai!'
#  'Aplikasi ini dimana materi sangat terstruktur berbagai fitur yang membantu, to the point dan sebagainya. Aplikasi ini sangat bermanfaat. 👍'
#  'Aplikasi sangat mudah digunakan, tampilan nya juga sangat bagus menarik, materi yang disajikan juga berkualitas, berkat aplikasi ini saya lebih mudah mengerti materi yang ingin saya pelajari, terus menjadi yang lebih baik dalam memajukan pendidikan di indonesia'
#  'bagus'
#  'Aplikasinya sangat mudah sekali digunakan, tampilannya juga sangat bagus. Yang paling saya suka adalah disini banyak sekali kelas gratisnya, ada webinarnya, dan bootcampnya juga gak mahal yang sangat membantu sekali terutama saya sendiri karena budget tidak menghalangi saya untuk belajar. Ayo tunggu apa lagi teman teman buruan download aplikasinya dan langsung pilih kursus yang kamu inginkan. Jangan sampai menyesal ya.'
#  'Kursusnya keren keren. Free courses, terutama di bidang IoT, AI, dan Data Science. Mudah dipahami. Selain itu banyak Webinar gratis. Top deh pokoknya BISA AI Academy'
#  'Tunggu Apalagi Buruan Download Aplikasi BISA AI Academy.!!! Recommended buat aplikasi ini, untuk yang mau menambah wawasan dan pengetahuan tentang dunia IT dan pemrograman. Materinya sangat mudah dipahami. Ada beberapa course yang gratis bisa diikutkan, event dan kompetisi berbagai hadiah. Yang paling suka ada e-sertificat yang gratis dapat diunduh setelah menyelesaikan course😍😍😍😍 Recommended 🥰🥰🥰 mudah diakses aplikasi tampilan nya sangat menarik.'
#  'Alhamdulillah, dengan bisa AI ini skill mengenai programing saya meningkat, ada kelas gratis juga. Dan juga disini terdapat fitur diskusi privat yang mana teman2 nanti dapat berdiskusi seperti saya menanyakan mengenai skripsi saya di bidang AI. Dan Alhamdulillah pemateri ny sangat berkompeten di bidangnya. Terima kasih'
#  'bagus' 'Very helpfull'
#  'Ada bug ketika ikut class academynya. Sering error ketika kembali ke materi silabus. Materi silabus sedikit sekali. Scoring quiz masih abu-abu mengenai jawaban benar dan salahnya. Materi silabus tulisan terlalu kecil ketika diubah mode horizontal tidak bisa. Sehingga unfriendly bgt untuk hp ukuran kecil. Jd pikir² untuk ikut bootcampnya.'
#  'bagus' 'Useful app.' 'Oke' 'bagus' 'Mantap aplikasinya sangat membantu'
#  'bagus'
#  'Entah kenapa, video pada materi tidak bisa di putar, video playernya tiba2 hilang, yang tersisa cuma teks saja'
#  'bagus'
#  'Aplikasinya sangat membantu terutama dalam media pembelajaran Mantapp...'
#  'Saat kemarin saya mencoba mempelajari platform AI mengenai basic python, jujur satu hal yang terlintas adalah rangkuman yang cukup baik, singkat padat dan jelas. Bahasanya juga sangat membantu pembaca untuk mengerti mengenai konsep konsep dalam coding. Terima kasih Bisa AI!'
#  'Seneng banget ketemu aplikasi ini, bisa belajar Data Science dengan mudah ditambah silabusnya mudah dimengerti, terimakasih BISA AI, tingkatkan terus.'
#  'Belajar seputar ai lebih mudah, materinya ringkas dan padat'
#  'Goooddd appsss'
#  'Wah saya baru daftar Kelas Gratis nya, cocok banget untuk pemula seperti saya 👍'
#  'bagus' 'Banyak fitur pembelajarannya, thanks! Maju terus'
#  'Utk HP vivo v5s silabus gx kebuka'
#  'Video di silabus hilang dan obsen E banyak hilang. Tolong di perbaiki agar bisa sya rubah bintang nya. Sya pakai hp samsung j2 pro'
#  'bagus' 'Updatenya semakin mantab'
#  'Video di materi tidak bisa ditampilkan sama sekali dan hanya teks. Di ujian sering muncul soal dari studi kasus materi yang tidak ada dalam teks, dan kemungkinan terdapat di video pembelajaran. Jika masalah video sudah bisa diatasi, auto bintang 5 :)'
#  'bagus'
#  'Materinya bermanfaat banget dong, untuk menunjang teknologi masa kini, dan banyak kelas gratis nya juga, bootcamp nya juga gak mahal, aplikasi nya sudah baik, sedang menunggu pengembangan berikut nya untuk semakin meningkatkan user experience nya. Terimakasih Bisa AI. Paling masukannya agar Tugas Akhirnya atau Final Projects yang diupload/dikumpulkan segera dinilai oleh Instruktur nya.'
#  'Materi yang di sediakan sangat mudah di pahami, dan sangat membantu untuk pemula ataupun yang baru belajar pada course yang dipilih, banyak juga course yang free, sehingga sangat membantu sekali,,,'
#  'Videonya baru loading tiba tiba menghilang, ada materi teks tapi singkat sekali, hanya menjelaskan konsep tanpa ada contoh pembahasannya. Waktu itu di kursus aljabar linier'
#  'Materinya cukup lengkap dan bisa membantu dalam pembelajaran'
#  'Keren bgt... Makasii banyak' 'bagus'
#  'Great apps. We can learn AI Online now'
#  'Sangat bermanfaat. Bisa belajar online sekarang terutama materi AI'
#  'Aplikasinya bagus dan sangat membantu pembelajaran saya'
#  'Great app! Has a very friendly user interface and very easy to use.'
#  'sangat bagus untuk para pemula dan yang mau lanjut ke tahap lebih expert aplikasi mudah digunakan'
#  'Sangat Membantu sekali dalam pembelajaran mengenai teknologi zaman kini, lanjutkan !!'
#  'Sangat mudah dipahami, aplikasi juga user friendly. good job' 'Mantul'
#  'Aplikasi bermanfaat untuk media pembelajaran era baru😊'
#  'Huhuu akhirnya ada platform buat belajar AI'
#  'Menjadi pilihan belajar terbaik...'
#  'Aplikasi yang saya butuhkan Mantap!!!' 'Mantab' 'bagus'
#  'Aplikasinya membantu untuk belajar, apalagi coursenya gk melulu bayar, bisa register yang free course. Semoga tambah bagus aplikasi kedepannya'
#  'Great apps'
#  'Aplikasi ini sangat menarik. Benar-benar memudahkan saya dalam belajar programming. Kalian jangan lupa untuk ikut download yah.'
#  'Aplikasi ini sangat membantu saya belajar programming. Pembelajarannya sangat menarik karena disertai video dan silabus yang lengkap. Tidak lupa ada quiz dan tugas akhir yang bisa dikerjakan. Dapatkan sertifikat dari setiap coursenya.'
#  'Saya sukaa IoT, materinya mudah dipahami. Next AI😁'
#  'untuk pemula seperti sy cocok banget beljar disini, lengkap smua fitur2nya ;)'
#  'Aplikasi yang mantap, coursenya juga banyak dan mudahan dipahami'
#  'Sory satu dulu klo emang good tambahin lg'
#  'Good job! Materi nya sangat mudah di pahami. Alangkah baik agak perlu berbaikan lagi ketika di quis ada beberapa soal yang blm ada code nya padahal suruh jawab apa output soal tersebut terimakasih'
#  'bagus'
#  'mantap ada course gratis nya. Terutama yg android development mudah dipahami'
#  'bagus' 'bagus' 'bagus' 'bagus'
#  'Course nya mantap banget pak, sejauh ini mantap banget materi²nya dan mudah di fahami. Tapi sedikit saran untuk materi yang ada komponen² seperti materi elektronik, sensor dl. lebih bagusnya diberikan gambar alatnya agar nantinya siswa yg belajar bisa langsung praktekin dengan membeli alatnya hehehe.... Semangat, semoga bisa menjadi platform yang besar dan mencerdaskan lebih banyak orang di indonesia'
#  'bagus'
#  'Aplikasi nya enak bgt di pake, aku yg ga ngerti AI jg jd semangat belajar nihh. Banyak jg course2 lain buat di pelajarin. Seru banget'
#  'Great app for learning' 'Materi menarik dan mudah dipahami'
#  'nice app for education'
#  'Keren, aplikasinya mudah di akses dan materi yang ditampilkan juga mudah dipahami'
#  'nocomment' 'Aplikasinya bagus, tampilannya bagus aku sukaaa'
#  'Aplikasi yang sangat lengkap untuk mulai belajar mengenai data science maupun iot. Banyak kelas gratisnya juga. Mantap'
#  'Masih belum ready 1. Ketika register new account error localhost something, setelah menekan berkali2 berhasil registered. 2. Ketika login password salah, padahal saved di autofill. Harus reset baru bisa masuk. 3. Menu lambat termuat, internet gada masalah. 4. Klik course A masuknya ke course B, berkali2 belum bisa masuk ke deskripsi lengkap course yg saya inginkan. Mohon diperbaiki. At least usable.'
#  'Sebetulnya sudah bagus course gratisnya tertata namun untuk menyelesaikan harus cari sumber lain bukan dari course yg sudah tersedia di bisa.AI'
#  'akhirnya bisa belajar online dimana aja. materinya sangat bermanfaat terutama AI'
#  'Permisi min mohon maaf appnya belum bisa di rotate lendscape ya? Maaf hp saya kecil nyoba install app pakai bluestacks biar lega, eh ternyata belum bisa lendscape 😔. Tapi terimakasih banyak kepada tim bisa ai telah mengadakan webinar yang menarik 😊'
#  'bagus' 'Mantap👍👍👍👍👍👍👍👍'
#  'Saya sudah daftar kelas data science, kok ketika masuk silabus tidak ada data ? Materi pembelajarannya gak ada di list, harus bagaimana jadinya ?'
#  'Belajar AI jadi lebih mudah' 'bagus'
#  'ngga usah download dah, ngapain.. text materi ngga ada, semua soalnya ngga ada penjabaran.. kasian yg udah beli, cukup gw aja yg kena.. yg lain mending belajar di google aja ada materinya..'
#  'nocomment' 'Sudah daftar tapi ga bisa login gimana yah' 'keren nih..'
#  'Hi, developer ! Overall udah bagus' 'bagus'
#  'Hai Kak. Kalau boleh nih, saya pingin kasih saran untuk pengembangan Apps nya agar diberi fitur penyimpanan external storage (Micro SD) biar hape2 jadul yg ukuran ROM nya terbatas bisa switches Apps ke Micro SD'
#  'Mon maaf nih Dev saya ikutan Coursenya "Dasar² Python" tapi untuk silabusnya malah "tidak ada data" gmn tuh?'
#  'Good apps.tapi untuk akses materi apakah password yg digunakan sama dengan passwors user id. Karena saya coba tidak bisa'
#  'Aplikasinya bagus dan mempermudah dalam belajar AI'
#  'Saran: Kalo sudah selesai kuis nya seharusnya ada keterangan jawabannya ya'
#  'Saran: Kalo sudaj selesai kuis harusnya ada penjelasan min, agar mudah dipahami lagi'
#  'Aplikasi nya sangat membantu dan materinya berbeda dari yg lain'
#  'Masih banyak bug. Pas buka materi langsung layar jadi hitam. Kadang langsung kembali ke menu utama sendiri pas error.'
#  'Good apps, sangat bermanfaat untuk menjelajah ilmu'
#  'Applikasi sangat baik, Bisa.ai adalah tempat belajar yang sangat tepat untuk pemula maupun yg sudah advance untuk belajar AI lebih dalam. Banyak pilihan bootcamp maupun webinar gratis yang membahas tentang AI. Saya mendapat beasiswa dari giveaway IG untuk free bootcamp. Saya mendapat banyak ilmu yg bermanfaat dari bootcamp yg diadakan bisa.ai academy ini. Terima kasih'
#  'Seneng banget ada aplikasi ini, kenapa aku baru nemu sekarang. Materinya mudah dipahami lagi, tingkatkan terus.'
#  'Simple dan tidak ribet'
#  'Menarik, designya juga bagus. Mungkin akan lebih bagus lagi jika ada websitenya untuk mempermudah proses belajar'
#  'KEREN aplikasinya lengkap, akademi, cari loker, semua ada disini, tampilannya juga menarik, materinya mudah dipahami, maju terus bisa AI 👍'
#  'Setiap masuk course, video yang ingin diplay hilang. Jadi sebenarnya tiap2 silabus ada materi berupa video atau tidak? Dan untuk materi yang menampilkan rumus (ambil contoh di course introduction data mining), tidak ada penjelasan penggunaan rumus, jadi bagi yg awam hal itu sangat menyulitkan dalam belajar. Untuk pembelajaran mungkin dibuat platform web demi kenyamanan pengguna. Terima kasih banyak sebelumnya..'
#  'bagus'
#  'Tolong tambahin fitur menyimpan jawaban min. Jadi ketika mengulang kuis tidak harus mengisi ulang jawaban sebelumnya.'
#  'bagus' 'bagus' '👍👍materinya bagus'
#  'Sangat membantu sekali untuk pemula yang tertarik pada bidang AI karena aplikasi dan materi yang ada didalamnya lengkap'
#  'Bisa ai sangat bermanfaat, sangat luar biasa dalam mengedukasi melalui event event dan webimarnya 🤗🤗🤗'
#  'APLIKASI KERRN BANGETTT. Awalnya bingung pengen mulai belajar AI IoT dll dari mana. Karena ilmu ini penting banget buat masa depann. Apalagi adanya strategi nasional AI behh pasti di cari banget. Course nya juga keren mantepp berboto dehhh. Makasihhhh'
#  'bagus'
#  'Terima kasih buat bisa ai, memberikan knowledge yang sangat bermanfaat buat masyarakat luas dibidang AI'
#  'Good bgt pokonya saya user baru... Recommended bgt buat belajar'
#  'Bisa ai academy sangat bermanfaat untuk berlatih secara mandiri tentang data science dan lain sebagainya juga terdapat course gratis dan berbayar, thansk bisa ai'
#  'bagus' 'bagus' 'bagus'
#  'Terima kasih BISA AI Academy, saya sekarang bisa belajar tentang Internet of Things dan lain lain. Silabusnya mudah dimengerti dan dipahami. Tugas dan quiz yang diberikan sangat membantu saya dalam belajar. Aplikasi yang Keren banget 👍🏻👍🏻'
#  'bagus' 'bagus' 'Bagus utk menambah ilmu pengetahuan' 'Well' 'bagus'
#  'bagus' 'bagus' 'bagus'
#  'Fiturnya banyak dan bisa juga mencari lowongan kerja, sangat memudahkan sekali'
#  'bagus' 'bagus']

# %%
#Lihat persebaran kata di review text yang positif
import matplotlib.pyplot as plt 
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(review) for review in new_df[new_df['Sentiment'].str.contains('Positif')]['Review Text'].dropna().unique() if len(review)>3) 
wordcloud = WordCloud(max_words=50,colormap='Set2', background_color="white").generate(text) 
plt.figure(figsize=(15,10)) 
plt.imshow(wordcloud) 
plt.show()

# %%
#Lihat persebaran kata di review text yang netral
import matplotlib.pyplot as plt 
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(review) for review in new_df[new_df['Sentiment'].str.contains('Netral')]['Review Text'].dropna().unique() if len(review)>3) 
wordcloud = WordCloud(max_words=50,colormap='Set2', background_color="white").generate(text) 
plt.figure(figsize=(15,10)) 
plt.imshow(wordcloud) 
plt.show()

# %%
#Lihat persebaran kata di review text yang negatif
import matplotlib.pyplot as plt 
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(review) for review in new_df[new_df['Sentiment'].str.contains('Negatif')]['Review Text'].dropna().unique() if len(review)>3) 
wordcloud = WordCloud(max_words=50,colormap='Set2', background_color="white").generate(text) 
plt.figure(figsize=(15,10)) 
plt.imshow(wordcloud) 
plt.show()

# %% [markdown]
# # Preprocessing Text

# %%
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.7/dist-packages (1.0.1)

# %%
#Pre Process Text untuk menghilangkan stop word
from nltk.tokenize import sent_tokenize, word_tokenize
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
import re
import string

def pre_process(text):
    # Case Folding: Lowercase
    # Merubah format teks menjadi format huruf kecil semua (lowercase).
    text = text.lower()

    # Case Folding: Removing Number
    # Menghapus karakter angka.
    text = re.sub(r"\d+", "", text)
    # Menghapus kata yg kurang dari 4 huruf
    text = re.sub(r'\b\w{1,3}\b', '', text)

    # Case Folding: Removing Punctuation
    # Menghapus karakter tanda baca.
    text = text.translate(str.maketrans("","",string.punctuation))

    #Case Folding: Removing Whitespace
    #Menghapus karakter kosong.
    text = text.strip()

    #Menghapus emote icon
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    text = emoji_pattern.sub(r'', text) # no emoji
    
    #Separating Sentences with Split () Method
    #Fungsi split() memisahkan string ke dalam list dengan spasi sebagai pemisah jika tidak ditentukan pemisahnya.
    pisah = text.split()
    # atau dengan re.split(r'\s+',text)

    #Filtering using sastrawi   
    # Ambil Stopword bawaan
    stop_factory = StopWordRemoverFactory().get_stop_words()
    more_stopword = ['dengan', 'ia','bahwa','oleh','ngga','jadi','doang','yg','tdk']
    # Merge stopword
    data = stop_factory + more_stopword
    # Menfilter stopword dengan tambahan stopword baru
    dictionary = ArrayDictionary(data)
    stopword = StopWordRemover(dictionary)
    text =  stopword.remove(text)

    return text

new_df['Review Text'] = new_df['Review Text'].apply(lambda x:pre_process(x))
new_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Star Rating                                        Review Text Sentiment
# 0           5                                              bagus   Positif
# 1           1  recommended course   nanya materi  mentornya m...   Negatif
# 2           5                                              bagus   Positif
# 3           5                                              bagus   Positif
# 4           5                                best  training apps   Positif

# %% [markdown]
# ## Cek Stop Word dalam bahasa Indonesia

# %%
factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()
print(stopwords)
# Out:
# ['yang', 'untuk', 'pada', 'ke', 'para', 'namun', 'menurut', 'antara', 'dia', 'dua', 'ia', 'seperti', 'jika', 'jika', 'sehingga', 'kembali', 'dan', 'tidak', 'ini', 'karena', 'kepada', 'oleh', 'saat', 'harus', 'sementara', 'setelah', 'belum', 'kami', 'sekitar', 'bagi', 'serta', 'di', 'dari', 'telah', 'sebagai', 'masih', 'hal', 'ketika', 'adalah', 'itu', 'dalam', 'bisa', 'bahwa', 'atau', 'hanya', 'kita', 'dengan', 'akan', 'juga', 'ada', 'mereka', 'sudah', 'saya', 'terhadap', 'secara', 'agar', 'lain', 'anda', 'begitu', 'mengapa', 'kenapa', 'yaitu', 'yakni', 'daripada', 'itulah', 'lagi', 'maka', 'tentang', 'demi', 'dimana', 'kemana', 'pula', 'sambil', 'sebelum', 'sesudah', 'supaya', 'guna', 'kah', 'pun', 'sampai', 'sedangkan', 'selagi', 'sementara', 'tetapi', 'apakah', 'kecuali', 'sebab', 'selain', 'seolah', 'seraya', 'seterusnya', 'tanpa', 'agak', 'boleh', 'dapat', 'dsb', 'dst', 'dll', 'dahulu', 'dulunya', 'anu', 'demikian', 'tapi', 'ingin', 'juga', 'nggak', 'mari', 'nanti', 'melainkan', 'oh', 'ok', 'seharusnya', 'sebetulnya', 'setiap', 'setidaknya', 'sesuatu', 'pasti', 'saja', 'toh', 'ya', 'walau', 'tolong', 'tentu', 'amat', 'apalagi', 'bagaimanapun']

# %% [markdown]
# ## Cek Stop Word dalam bahasa inggris

# %%
from sklearn.feature_extraction import text
print(text.ENGLISH_STOP_WORDS)
# Out:
# frozenset({'by', 'thereby', 'becomes', 'this', 'nothing', 'through', 'during', 'somehow', 'cry', 'we', 'everywhere', 'been', 'up', 'whence', 'made', 'of', 'while', 'might', 'whenever', 'from', 'such', 'always', 'ie', 'top', 'against', 'then', 'co', 'because', 'afterwards', 'out', 'ltd', 'all', 'below', 'others', 'after', 'its', 'along', 'empty', 'seem', 'hundred', 'each', 'why', 'not', 'was', 'onto', 'see', 'their', 'name', 'most', 'further', 'former', 'often', 'myself', 'the', 'be', 'well', 'about', 'what', 'or', 'yourself', 'my', 'anyway', 'due', 'therefore', 'who', 'hereby', 'un', 'ever', 'both', 'own', 'could', 'are', 'few', 'go', 're', 'system', 'back', 'sincere', 'that', 'everything', 'least', 'amoungst', 'front', 'latterly', 'and', 'how', 'fill', 'four', 'mine', 'seems', 'inc', 'no', 'can', 'in', 'them', 'whereas', 'once', 'hers', 'whose', 'none', 'so', 'latter', 'amount', 'next', 'fire', 'though', 'moreover', 'again', 'many', 'meanwhile', 'twelve', 'under', 'either', 'too', 'cannot', 'although', 'mill', 'without', 'she', 'among', 'rather', 'yourselves', 'himself', 'these', 'sixty', 'however', 'formerly', 'thereafter', 'third', 'thick', 'becoming', 'cant', 'take', 'hereafter', 'also', 'someone', 'had', 'is', 'must', 'beyond', 'ours', 'show', 'whereupon', 'off', 'his', 'two', 'should', 'wherever', 'your', 'within', 'describe', 'he', 'one', 'beforehand', 'whereby', 'sometime', 'otherwise', 'still', 'thence', 'which', 'move', 'those', 'will', 'only', 'nobody', 'enough', 'besides', 'detail', 'across', 'neither', 'several', 'mostly', 'when', 'now', 'throughout', 'serious', 'ten', 'above', 'perhaps', 'me', 'anyhow', 'three', 'more', 'some', 'con', 'to', 'except', 'whatever', 'first', 'at', 'eleven', 'behind', 'thin', 'between', 'twenty', 'much', 'hence', 'amongst', 'hasnt', 'our', 'down', 'where', 'whereafter', 'for', 'anywhere', 'noone', 'fifty', 'herein', 'else', 'eg', 'around', 'have', 'side', 'eight', 'part', 'whither', 'may', 'etc', 'you', 'am', 'nowhere', 'put', 'become', 'somewhere', 'already', 'became', 'another', 'her', 'upon', 'him', 'six', 'any', 'into', 'something', 'together', 'themselves', 'anyone', 'de', 'it', 'being', 'indeed', 'before', 'alone', 'elsewhere', 'itself', 'has', 'were', 'towards', 'an', 'with', 'than', 'over', 'yours', 'almost', 'therein', 'every', 'since', 'full', 'bottom', 'per', 'via', 'toward', 'keep', 'wherein', 'couldnt', 'find', 'very', 'would', 'done', 'they', 'never', 'if', 'thru', 'whether', 'please', 'do', 'here', 'us', 'seeming', 'get', 'same', 'call', 'give', 'other', 'nor', 'whoever', 'yet', 'thereupon', 'nine', 'fifteen', 'until', 'interest', 'hereupon', 'herself', 'namely', 'beside', 'found', 'whole', 'ourselves', 'even', 'on', 'five', 'i', 'there', 'as', 'but', 'bill', 'anything', 'whom', 'a', 'thus', 'nevertheless', 'less', 'forty', 'everyone', 'last', 'seemed', 'sometimes'})

# %%
print(new_df['Review Text'].values)
# Out:
# ['bagus'
#  'recommended course   nanya materi  mentornya malah dibatasi topiknya padahal relevan sama course  diambil waktu  dikasih  mentor  chat  dibales balas sampe waktu workshop  habis   balasan materi  jelas  implementasi   penjelasan metode  youtube lebih membantu  dibanding  semoga  upgrade  kualitas mentor  materinya'
#  'bagus' 'bagus' 'best  training apps'
#  'jangan buat aplikasi  kalo kagak dipake' 'bagus' 'gudangnya pengetahuan'
#  'bagus' 'bagus' 'bagus' 'bagus'
#  'kelas excel  analytic nilai quiz   perbaiki dong masa  soal nilai  point  soal kalau bener semua cuman dapet  minimal lulus'
#  'bagus'
#  'aplikasinya bagus tetapi  saran tampilan tulisan materi  silabus kecil sekali rumus terkadang muncul kompetisi dibedakan dong sudah lewat sama sedang berlangsung'
#  'bagus' 'sangat membantu' 'nocomment'
#  '  course  nilai kuisnya mentok    padahal jawabannya yakin benar berkali dicek  disesuaikan materi mohon bantuannya'
#  'bagus'
#  'aplikasi anak bangsa luar biasa sangat membantu orang terjun kedunia   ingin tahu'
#  'bagus'
#  'aplikasinya sangat membantu banget nambah ilmu sama relasi goks  pokonya '
#  'aplikasinya sangat bagus  kerennn banget buat belajar data science   recommended'
#  'great   learning'
#  'application  very helpful  understanding basic material' 'bagus' 'bagus'
#  'mantap'
#  'materinya keren silabus ringkasan mudah pahami pemula  tunggu pengembangan sistem selanjutnya '
#  'banyak ilmu daging  dalamnya '
#  'tempat belajar user friendly  punya komunitas ramah dicoba'
#  'aplikasinya keren banget'
#  'aplikasinya keren abis baru tahu ternyata  course machine learning'
#  'aplikasi keren ngebantu banget buat belajar dunia digital buat  butuh sumber belajar mantapp terus kembangkan minn'
#  'mengerjakan course gratis menurutku aplikasinya  bagus ilmu   otak  mungkin buat  tugas  quiz  sedikit   scrooll  diulang quiz  lancar  kurang   karna device  bagaimana  saran tambahkan info fitur alur buat belajar tiap course   misal kalo  atau data science urutan mulai course darimana dimulai mungkin sedikit membantu'
#  'bagus'
#  'aplikasinya bagus baru mencoba course python dasar  saya materinya mudah dimengerti mungkin sedikit kekurang dibagian kuis uang terkadang  bisa scroll overal good application  learning'
#  'mantap' 'nice   learning  easy'
#  'mantap buat latian belajar  menambah pengalaman'
#  'keren materinya lengkap ' 'bagus sekali'
#  'sangat bermanfaat tersedia banyak sekali kelas sangat membantu  tersedia bootcamp harga terjangkau'
#  '' 'bagus'
#  'aplikasi  dapat mempelajari materi² banyak dibutuhkan didalam dunia  materi diberikan sangat update sesuai perkembangan zaman recomended  orang awam ingin belajar dunia  khususnya bidang'
#  'terimakasih  materi  sangat bermanfaat'
#  'materi tersedia  aplikasi sangat banyak  bagus menambah ilmu pengetahuan '
#  'bagus'
#  'aplikasi karya anak bangsa  sangat membantu sekali mengadakan kursus webinar free  berbayar buat orang² pemula awam mahasiswa umum  orang    belajar lebih lagi mengenal ilmu artificial inteligency   sedang viral  masa kini recommended   pokoknya pengajar   humble  expert  didlm mengajari bidang    tunggu guys buruan download aplikasi    langsung pilih kursus   inginkan   menyesal  kemudian hari'
#  'sangat membantu sekali aplikasinya mengenal update terbaru seputar teknologi  bisa memperdalam ilmu'
#  'materi diberikan cukup padat walaupun free course mampu mengakomodasi materi dasar terutama sistem cerdas'
#  'mantap ilmunya semoga semakin bermanfaat'
#  'aplikasi  menarik   fitur buat freelance   lowongan kerja'
#  'applikasinya keren  free course bisa pelajari  course berbayar yang kalah menarik buat yang tertarik  dunia   pemrograman komputer bahasa pemrograman  internet  things sangat bermanfaat'
#  'jujur senang sekali menemukan aplikasi  sangat membantu belajar  bidang saya sukai terima kasih'
#  'aplikasi  materi sangat terstruktur berbagai fitur membantu   point  sebagainya aplikasi  sangat bermanfaat '
#  'aplikasi sangat mudah digunakan tampilan  sangat bagus menarik materi disajikan berkualitas berkat aplikasi  lebih mudah mengerti materi ingin pelajari terus menjadi lebih baik memajukan pendidikan  indonesia'
#  'bagus'
#  'aplikasinya sangat mudah sekali digunakan tampilannya sangat bagus paling suka disini banyak sekali kelas gratisnya  webinarnya  bootcampnya  mahal sangat membantu sekali terutama sendiri budget menghalangi untuk belajar  tunggu  teman teman buruan download aplikasinya  langsung pilih kursus kamu inginkan jangan menyesal'
#  'kursusnya keren keren free courses terutama  bidang    data science mudah dipahami  banyak webinar gratis   pokoknya  academy'
#  'tunggu buruan download aplikasi  academy recommended buat aplikasi   menambah wawasan  pengetahuan dunia   pemrograman materinya sangat mudah dipahami  beberapa course gratis diikutkan event  kompetisi berbagai hadiah paling suka  sertificat yang gratis diunduh menyelesaikan course recommended  mudah diakses aplikasi tampilan  sangat menarik'
#  'alhamdulillah bisa   skill mengenai programing meningkat  kelas gratis  disini terdapat fitur diskusi privat mana teman dapat berdiskusi menanyakan mengenai skripsi saya  bidang   alhamdulillah pemateri  sangat berkompeten  bidangnya terima kasih'
#  'bagus' 'very helpfull'
#  'ikut class academynya sering error kembali  materi silabus materi silabus sedikit sekali scoring quiz  mengenai jawaban benar  salahnya materi silabus tulisan terlalu kecil diubah mode horizontal bisa unfriendly   ukuran kecil  pikir² ikut bootcampnya'
#  'bagus' 'useful' '' 'bagus' 'mantap aplikasinya sangat membantu' 'bagus'
#  'entah video materi bisa  putar video playernya tiba hilang tersisa cuma teks'
#  'bagus' 'aplikasinya sangat membantu terutama media pembelajaran mantapp'
#  'kemarin mencoba mempelajari platform  mengenai basic python jujur satu  terlintas rangkuman cukup baik singkat padat  jelas bahasanya sangat membantu pembaca mengerti mengenai konsep konsep coding terima kasih'
#  'seneng banget ketemu aplikasi  belajar data science mudah ditambah silabusnya mudah dimengerti terimakasih  tingkatkan terus'
#  'belajar seputar  lebih mudah materinya ringkas  padat' 'goooddd appsss'
#  'baru daftar kelas gratis  cocok banget pemula saya ' 'bagus'
#  'banyak fitur pembelajarannya thanks maju terus' 'vivo  silabus  kebuka'
#  'video  silabus hilang  obsen  banyak hilang  perbaiki bisa  rubah bintang   pakai  samsung'
#  'bagus' 'updatenya semakin mantab'
#  'video  materi bisa ditampilkan sama sekali  teks  ujian sering muncul soal studi kasus materi tidak  teks  kemungkinan terdapat  video pembelajaran masalah video bisa diatasi auto bintang'
#  'bagus'
#  'materinya bermanfaat banget dong menunjang teknologi masa kini  banyak kelas gratis  bootcamp   mahal aplikasi  baik sedang menunggu pengembangan berikut  semakin meningkatkan user experience  terimakasih  paling masukannya tugas akhirnya final projects diuploaddikumpulkan segera dinilai instruktur'
#  'materi  sediakan sangat mudah  pahami  sangat membantu pemula ataupun baru belajar course dipilih banyak course free sangat membantu sekali'
#  'videonya baru loading tiba tiba menghilang  materi teks singkat sekali menjelaskan konsep  contoh pembahasannya waktu   kursus aljabar linier'
#  'materinya cukup lengkap  membantu pembelajaran' 'keren  makasii banyak'
#  'bagus' 'great apps   learn  online'
#  'sangat bermanfaat belajar online sekarang terutama materi'
#  'aplikasinya bagus  sangat membantu pembelajaran'
#  'great    very friendly user interface  very easy'
#  'sangat bagus para pemula   lanjut  tahap lebih expert aplikasi mudah digunakan'
#  'sangat membantu sekali pembelajaran mengenai teknologi zaman kini lanjutkan'
#  'sangat mudah dipahami aplikasi user friendly good' 'mantul'
#  'aplikasi bermanfaat media pembelajaran  baru'
#  'huhuu akhirnya  platform buat belajar' 'menjadi pilihan belajar terbaik'
#  'aplikasi saya butuhkan mantap' 'mantab' 'bagus'
#  'aplikasinya membantu belajar coursenya  melulu bayar register free course semoga tambah bagus aplikasi kedepannya'
#  'great apps'
#  'aplikasi  sangat menarik benarbenar memudahkan dalam belajar programming kalian jangan lupa ikut download'
#  'aplikasi  sangat membantu belajar programming pembelajarannya sangat menarik disertai video  silabus lengkap lupa  quiz  tugas akhir bisa dikerjakan dapatkan sertifikat setiap coursenya'
#  'sukaa  materinya mudah dipahami next '
#  'pemula  cocok banget beljar disini lengkap smua fiturnya'
#  'aplikasi mantap coursenya banyak  mudahan dipahami'
#  'sory satu dulu  emang good tambahin'
#  'good  materi  sangat mudah  pahami alangkah baik perlu berbaikan ketika  quis  beberapa soal   code  padahal suruh jawab  output soal tersebut terimakasih'
#  'bagus'
#  'mantap  course gratis  terutama  android development mudah dipahami'
#  'bagus' 'bagus' 'bagus' 'bagus'
#  'course  mantap banget  sejauh  mantap banget materi²nya  mudah  fahami sedikit saran materi  komponen² materi elektronik sensor  lebih bagusnya diberikan gambar alatnya nantinya siswa  belajar langsung praktekin membeli alatnya hehehe semangat semoga menjadi platform besar  mencerdaskan lebih banyak orang  indonesia'
#  'bagus'
#  'aplikasi  enak   pake    ngerti    semangat belajar nihh banyak  course buat  pelajarin seru banget'
#  'great   learning' 'materi menarik  mudah dipahami' 'nice   education'
#  'keren aplikasinya mudah  akses  materi ditampilkan mudah dipahami'
#  'nocomment' 'aplikasinya bagus tampilannya bagus  sukaaa'
#  'aplikasi sangat lengkap mulai belajar mengenai data science maupun  banyak kelas gratisnya mantap'
#  'ready  register  account error localhost something menekan berkali berhasil registered  login password salah padahal saved  autofill reset baru masuk  menu lambat termuat internet gada masalah  klik course  masuknya  course  berkali belum bisa masuk  deskripsi lengkap course  inginkan mohon diperbaiki  least usable'
#  'bagus course gratisnya tertata untuk menyelesaikan cari sumber bukan course  sudah tersedia '
#  'akhirnya belajar online  materinya sangat bermanfaat terutama'
#  'permisi  mohon maaf appnya  rotate lendscape  maaf  kecil nyoba install  pakai bluestacks biar lega  ternyata bisa lendscape  terimakasih banyak  bisa  mengadakan webinar menarik '
#  'bagus' 'mantap'
#  'sudah daftar kelas data science  masuk silabus  data  materi pembelajarannya    list bagaimana jadinya'
#  'belajar  lebih mudah' 'bagus'
#  'usah download  ngapain text materi  semua soalnya  penjabaran kasian  udah beli cukup    kena  mending belajar  google   materinya'
#  'nocomment' 'daftar  login gimana' 'keren'
#  'developer  overall udah bagus' 'bagus'
#  'kalau  pingin kasih saran pengembangan apps  diberi fitur penyimpanan external storage micro  biar hape jadul  ukuran   terbatas switches apps  micro'
#  'maaf   ikutan coursenya dasar² python untuk silabusnya malah  data'
#  'good appstapi akses materi password  digunakan sama passwors user  saya coba bisa'
#  'aplikasinya bagus  mempermudah belajar'
#  'saran kalo selesai kuis   keterangan jawabannya'
#  'saran kalo sudaj selesai kuis harusnya  penjelasan  mudah dipahami'
#  'aplikasi  sangat membantu  materinya berbeda '
#  'banyak   buka materi langsung layar hitam kadang langsung  menu utama sendiri  error'
#  'good apps sangat bermanfaat menjelajah ilmu'
#  'applikasi sangat baik adalah tempat belajar sangat tepat pemula maupun  advance belajar  lebih banyak pilihan bootcamp maupun webinar gratis membahas  mendapat beasiswa giveaway  free bootcamp mendapat banyak ilmu  bermanfaat bootcamp  diadakan academy  terima kasih'
#  'seneng banget  aplikasi   baru nemu sekarang materinya mudah dipahami tingkatkan terus'
#  'simple  ribet'
#  'menarik designya bagus mungkin lebih bagus jika  websitenya mempermudah proses belajar'
#  'keren aplikasinya lengkap akademi cari loker semua  disini tampilannya menarik materinya mudah dipahami maju terus  '
#  'masuk course video ingin diplay hilang sebenarnya tiap silabus  materi berupa video  materi menampilkan rumus ambil contoh  course introduction data mining tidak  penjelasan penggunaan rumus bagi  awam   sangat menyulitkan belajar pembelajaran mungkin dibuat platform  kenyamanan pengguna terima kasih banyak sebelumnya'
#  'bagus'
#  'tambahin fitur menyimpan jawaban  ketika mengulang kuis harus mengisi ulang jawaban sebelumnya'
#  'bagus' 'bagus' 'materinya bagus'
#  'sangat membantu sekali pemula tertarik bidang  aplikasi  materi  didalamnya lengkap'
#  ' sangat bermanfaat sangat luar biasa mengedukasi melalui event event  webimarnya '
#  'aplikasi kerrn bangettt awalnya bingung pengen mulai belajar    mana ilmu  penting banget buat masa depann adanya strategi nasional  behh  cari banget course  keren mantepp berboto dehhh makasihhhh'
#  'bagus'
#  'terima kasih buat  memberikan knowledge sangat bermanfaat buat masyarakat luas dibidang'
#  'good  pokonya user baru recommended  buat belajar'
#  ' academy sangat bermanfaat berlatih mandiri data science  sebagainya terdapat course gratis  berbayar thansk'
#  'bagus' 'bagus' 'bagus'
#  'terima kasih  academy sekarang belajar internet  things  lain silabusnya mudah dimengerti  dipahami tugas  quiz diberikan sangat membantu dalam belajar aplikasi keren banget '
#  'bagus' 'bagus' 'bagus  menambah ilmu pengetahuan' 'well' 'bagus' 'bagus'
#  'bagus' 'bagus'
#  'fiturnya banyak  juga mencari lowongan kerja sangat memudahkan sekali'
#  'bagus' 'bagus']

# %% [markdown]
# # Melihat grafik persebaran perkata & 2 kata

# %%
from sklearn.feature_extraction.text import CountVectorizer
def top_n_ngram(corpus,n = None,ngram = 1):
    vec = CountVectorizer(stop_words = 'english',ngram_range=(ngram,ngram)).fit(corpus)
    bag_of_words = vec.transform(corpus) #Have the count of  all the words for each review
    sum_words = bag_of_words.sum(axis =0) #Calculates the count of all the word in the whole review
    words_freq = [(word,sum_words[0,idx]) for word,idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq,key = lambda x:x[1],reverse = True)
    return words_freq[:n]

# %%
common_words = top_n_ngram(new_df['Review Text'], 20,1)
df = pd.DataFrame(common_words, columns = ['ReviewText' , 'count'])
plt.figure(figsize =(20,5))
df.groupby('ReviewText').sum()['count'].sort_values(ascending=False).plot(
kind='bar', title='Top 20 unigrams in review after removing stop words')

# %%
common_words = top_n_ngram(new_df['Review Text'], 20,2)
df = pd.DataFrame(common_words, columns = ['ReviewText' , 'count'])
plt.figure(figsize =(20,5))
df.groupby('ReviewText').sum()['count'].sort_values(ascending=False).plot(
kind='bar', title='Top 20 bigrams in review after removing stop words')

# %%
#Lihat persebaran kata di review text nya setelah di pre process
import matplotlib.pyplot as plt 
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(review) for review in new_df[new_df['Sentiment'].str.contains('Positif')]['Review Text'].dropna().unique() if len(review)>3) 
wordcloud = WordCloud(max_words=50,colormap='Set2', background_color="white").generate(text) 
plt.figure(figsize=(15,10)) 
plt.imshow(wordcloud) 
plt.show()

# %%
import matplotlib.pyplot as plt 
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(review) for review in new_df[new_df['Sentiment'].str.contains('Netral')]['Review Text'].dropna().unique() if len(review)>3) 
wordcloud = WordCloud(max_words=50,colormap='Set2', background_color="white").generate(text) 
plt.figure(figsize=(15,10)) 
plt.imshow(wordcloud) 
plt.show()

# %%
import matplotlib.pyplot as plt 
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(review) for review in new_df[new_df['Sentiment'].str.contains('Negatif')]['Review Text'].dropna().unique() if len(review)>3) 
wordcloud = WordCloud(max_words=50,colormap='Set2', background_color="white").generate(text) 
plt.figure(figsize=(15,10)) 
plt.imshow(wordcloud) 
plt.show()

# %%
#drop column Star Rating
new_df = new_df.drop(columns=['Star Rating'])

# %% [markdown]
# # Pembuatan Model

# %% [markdown]
# ## Memisah antara data latih dan test

# %%
# #Merubah nilai target dari string ke array
# from sklearn.preprocessing import OneHotEncoder

# X = OneHotEncoder(sparse=False).fit_transform(

#   new_df['Review Text'].to_numpy().reshape(-1, 1)

# )

# %%
y = new_df['Sentiment']
X = new_df['Review Text']
print(y.value_counts())

#Merubah nilai target dari string ke numerik
from sklearn.preprocessing import LabelEncoder
y = LabelEncoder().fit_transform(y)
print(pd.DataFrame(y).value_counts())
# Out:
# Positif    172
# Negatif     14
# Netral       5
# Name: Sentiment, dtype: int64
# 2    172
# 0     14
# 1      5
# dtype: int64

# %%
X
# Out:
# 0                                                 bagus
# 1     recommended course   nanya materi  mentornya m...
# 2                                                 bagus
# 3                                                 bagus
# 4                                   best  training apps
#                             ...
# 28                                                bagus
# 29                                                bagus
# 30    fiturnya banyak  juga mencari lowongan kerja s...
# 31                                                bagus
# 32                                                bagus
# Name: Review Text, Length: 191, dtype: object

# %%
y
# Out:
# array([2, 0, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        0, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 0, 2, 2, 0,
#        2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0,
#        2, 2, 1, 1, 2, 2, 2, 2, 1, 2, 2, 0, 0, 1, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2])

# %%
from collections import Counter
import matplotlib.pyplot as plt
# summarize distribution
counter = Counter(y)
for k,v in counter.items():
	per = v / len(y) * 100
	print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
# plot the distribution
plt.bar(counter.keys(), counter.values())
plt.show()
# Out:
# Class=2, n=172 (90.052%)
# Class=0, n=14 (7.330%)
# Class=1, n=5 (2.618%)

# %%
from sklearn.model_selection import train_test_split
# Create a train-test split of these variables
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1)
print("Training data size : ", X_train.shape)
print("Test data size : ", X_test.shape)
# Out:
# Training data size :  (152,)
# Test data size :  (39,)

# %%
X_train
# Out:
# 6                                                 bagus
# 7     aplikasinya keren abis baru tahu ternyata  cou...
# 0                            great apps   learn  online
# 29    course  mantap banget  sejauh  mantap banget m...
# 32    aplikasi sangat mudah digunakan tampilan  sang...
#                             ...
# 0     aplikasi sangat lengkap mulai belajar mengenai...
# 4     permisi  mohon maaf appnya  rotate lendscape  ...
# 7                                                 bagus
# 7     sudah daftar kelas data science  masuk silabus...
# 11    aplikasinya bagus baru mencoba course python d...
# Name: Review Text, Length: 152, dtype: object

# %% [markdown]
# # Features Extraction dengan TfidfVectorizer sekaligus penentuan model

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier 
from sklearn import metrics


LSVC_model = Pipeline([
                       ('tfidf', TfidfVectorizer()),
                       ('clf', LinearSVC())
                     ])
# LSVC_model = LinearSVC()
LSVC_model.fit(X_train, y_train)
LSVC_predictions = LSVC_model.predict(X_test)
print(metrics.confusion_matrix(y_test,LSVC_predictions))
print(metrics.classification_report(y_test,LSVC_predictions))
print(metrics.accuracy_score(LSVC_predictions, y_test))
# Out:
# [[ 1  2]
#  [ 0 36]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50         3
#            2       0.95      1.00      0.97        36
#
#     accuracy                           0.95        39
#    macro avg       0.97      0.67      0.74        39
# weighted avg       0.95      0.95      0.94        39
#
# 0.9487179487179487

# %%
NB_model = Pipeline([
                       ('tfidf', TfidfVectorizer()),
                       ('clf', MultinomialNB())
                     ])
# NB_model = MultinomialNB()
NB_model.fit(X_train, y_train)
NB_predictions = NB_model.predict(X_test)
print(metrics.confusion_matrix(y_test,NB_predictions))
print(metrics.classification_report(y_test,NB_predictions))
print(metrics.accuracy_score(NB_predictions, y_test))
# Out:
# [[ 0  3]
#  [ 0 36]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            2       0.92      1.00      0.96        36
#
#     accuracy                           0.92        39
#    macro avg       0.46      0.50      0.48        39
# weighted avg       0.85      0.92      0.89        39
#
# 0.9230769230769231
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
RF_model = Pipeline([('tfidf', TfidfVectorizer()),
                     ('clf', RandomForestClassifier())])
# RF_Model = RandomForestClassifier()
RF_model.fit(X_train,y_train)
RF_predictions = RF_model.predict(X_test)
print(metrics.confusion_matrix(y_test,RF_predictions))
print(metrics.classification_report(y_test,RF_predictions))
print(metrics.accuracy_score(RF_predictions, y_test))
# Out:
# [[ 0  3]
#  [ 0 36]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            2       0.92      1.00      0.96        36
#
#     accuracy                           0.92        39
#    macro avg       0.46      0.50      0.48        39
# weighted avg       0.85      0.92      0.89        39
#
# 0.9230769230769231
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
MLP_model = Pipeline([('tfidf', TfidfVectorizer()),
                     ('clf', MLPClassifier())])
# MLP_model = MLPClassifier()
MLP_model.fit(X_train,y_train)
MLP_predictions = MLP_model.predict(X_test)
print(metrics.confusion_matrix(y_test,MLP_predictions))
print(metrics.classification_report(y_test,MLP_predictions))
print(metrics.accuracy_score(MLP_predictions, y_test))
# Out:
# [[ 1  2]
#  [ 0 36]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50         3
#            2       0.95      1.00      0.97        36
#
#     accuracy                           0.95        39
#    macro avg       0.97      0.67      0.74        39
# weighted avg       0.95      0.95      0.94        39
#
# 0.9487179487179487
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
sample_string = "materinya lengkap dan sangat membantu sekali"
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer(max_features = 636)

sample_string_counts = count_vect.fit_transform([sample_string])
print(sample_string_counts.shape)
print(count_vect.get_feature_names())
# Out:
# (1, 6)
# ['dan', 'lengkap', 'materinya', 'membantu', 'sangat', 'sekali']

# %%
count_vect.fit_transform(["a place to listen to music it smaking its way to the us"]).shape
# Out:
# (1, 10)

# %%
sample_string = "materinya lengkap dan sangat membantu sekali"
print(LSVC_model.predict([sample_string]))
print(NB_model.predict([sample_string]))
print(RF_model.predict([sample_string]))
print(MLP_model.predict([sample_string]))
# Out:
# [2]
# [2]
# [2]
# [2]

# %%
sample_string = "jelek tidak bermutu"

# %%
print(LSVC_model.predict([sample_string]))
print(NB_model.predict([sample_string]))
print(RF_model.predict([sample_string]))
print(MLP_model.predict([sample_string]))
# Out:
# [2]
# [2]
# [2]
# [2]

# %%
# from keras.models import load_model

# model.save('Waris_LSTM-SentimentAnalysis.pickle')  # creates a HDF5 file 'my_model.h5'

# %%
# # returns a compiled model
# model = load_model('Waris_LSTM-SentimentAnalysis.pickle')
